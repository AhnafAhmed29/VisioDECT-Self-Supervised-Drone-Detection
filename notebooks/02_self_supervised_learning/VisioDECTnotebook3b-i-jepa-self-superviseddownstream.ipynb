# %% [markdown]
# # Computer Vision
# ## Notebook 3b — I-JEPA Backbone → YOLOv26-s Fine-Tune @ 20% Labels
#
# | | |
# |---|---|
# | **Detector** | YOLOv26-s (Part A best; frozen fair-comparison protocol from Part A) |
# | **Backbone init** | **I-JEPA** checkpoint from Notebook 3a (16,483 unlabelled pool images) |
# | **Label budget** | **ρ = 0.20** → 4,121 labelled images, nested via the shared `pool_rank` |
# | **Baselines** | Same detector from **random init** and **COCO weights** at the same ρ (§4.2 step 6) |
# | **Evaluation** | 10% validation + 10% test holdout from the shared Part B partition |
#
# **Covers step in order:** CONFIG → subset builder (counts + disjointness)
# → **weight surgery with the mandatory layer-mapping report** → 50-epoch fine-tune (demo
# inference first) → evaluation on val + test with PR curve and 6–8 qualitative predictions →
# random-init and COCO baselines → comparison table (+ optional 100%-label Part A reference).

# %% [markdown]
# ## 0. How to Run This Notebook on Kaggle
# 1. **Create**: Kaggle → *Create* → *New Notebook* → File → Import Notebook. Accelerator =
#    **GPU T4 x2**; Internet = **On** (ultralytics install + `yolo26s.pt` for the COCO baseline).
# 2. **Attach three inputs** (*Add Input*):
#    - the **checkpoint dataset published from Notebook 3a** (e.g.
#      `groupXX-partb-ssl-checkpoints`) — provides `ijepa_yolo26s_backbone.pt`,
#      `partB_partition.csv`, and `ijepa_pretrain_summary.json`. (Attaching 3a's notebook
#      output directly also works; the discovery cell searches for the files.)
#    - **Part A Notebook 1's output** (`visiodect_yolo/`) — the label files are restored from
#      here for the 20% subset.
#    - *(optional, for the 100%-label reference line)* **Part A Notebook 4's output** — its
#      `checkpoints/yolov26s_best.pt` is evaluated on the new test holdout (§2 prerequisite 5).
# 3. **Budget**: three 50-epoch fine-tunes (I-JEPA / random / COCO) at 4,121 train images.
#    Part A measured YOLOv26-s at 322.6 min for 50 epochs on 14,422 images → each run scales to
#    ~90–100 min → **~5 h total**, safe for *Save Version → Save & Run All*. The §4.2 "run
#    baselines once, reuse" rule: Notebooks 1b/2b/4b should attach **this** notebook's output
#    and set `RUN_BASELINES = False` — the comparison cell merges the saved baseline JSONs.
# 4. Fill the group fields, **Run all**, commit, set **Public**.

# %% [markdown]
# ## 1. CONFIG —
# Architecture, checkpoint path, ρ, the shared seed, and the **frozen fair-comparison
# protocol**: identical resolution, batch, epochs, optimiser/LR schedule, augmentation,
# thresholds and seed for every run in every Part B notebook — only the backbone
# initialisation (and, in the bonus, ρ) may vary.

# %%
# =============================== CONFIG ===============================

SSL_METHOD   = "ijepa"
YOLO_ARCH    = "yolo26s.yaml"     # Part A best architecture (see justification memo)
COCO_WEIGHTS = "yolo26s.pt"       # baseline (b): default COCO-pretrained weights
RHO          = 0.20               # label fraction (assignment standard budget)
PARTB_SEED   = 445                # THE shared Part B seed (partition + all sampling)

# ---- frozen fair-comparison fine-tuning protocol (== Part A YOLO protocol) ----
EPOCHS, PATIENCE  = 50, 25        # assignment standard: 50 downstream epochs
IMGSZ, BATCH      = 640, 16
WORKERS           = 4
OPTIMIZER, LR0    = "auto", 0.01  # ultralytics-resolved; lr0 fallback declared
WARMUP_EPOCHS     = 3
CLOSE_MOSAIC      = 10
FLIPLR, FLIPUD, DEGREES = 0.5, 0.0, 0.0
HSV_H, HSV_S, HSV_V     = 0.015, 0.7, 0.4
MIXUP, COPY_PASTE       = 0.0, 0.0
CONF_EVAL, IOU_NMS      = 0.25, 0.7

RUN_BASELINES = True   # this notebook trains the two anchors; 1b/2b/4b set False
                       # and reuse the JSONs from this notebook's attached output.
RUN_REFERENCE = True   # evaluate the Part A 100%-label checkpoint on the NEW test
                       # holdout if attached (graceful skip otherwise).

# ---- input discovery (manual overrides take precedence) -----------------------
CKPT_MANUAL      = None   # e.g. Path(".../ijepa_yolo26s_backbone.pt")
PARTITION_MANUAL = None   # e.g. Path(".../partB_partition.csv")
NB1_DIR_MANUAL   = None   # e.g. Path(".../visiodect_yolo")
PARTA_CKPT_MANUAL = None  # e.g. Path(".../checkpoints/yolov26s_best.pt")

# ---- paths --------------------------------------------------------------------
WORK_ROOT   = "/kaggle/working"
DATA_ROOT   = f"{WORK_ROOT}/partB_data"            # materialised YOLO dataset
RUN_PROJECT = f"{WORK_ROOT}/runs_partB"
SURGERY_CKPT = f"{WORK_ROOT}/ijepa_surgery_init.pt"
DOWNSTREAM_DIR = f"{WORK_ROOT}/partB_downstream"   # per-run metric JSONs (reused by 1b/2b/4b)
CKPT_OUT    = f"{WORK_ROOT}/checkpoints"           # fine-tuned best.pt per init

print(f"CONFIG | {SSL_METHOD} -> {YOLO_ARCH} @ rho={RHO} | {EPOCHS} epochs, "
      f"imgsz {IMGSZ}, batch {BATCH} | seed {PARTB_SEED} | baselines={RUN_BASELINES}")
# Out:
# CONFIG | ijepa -> yolo26s.yaml @ rho=0.2 | 50 epochs, imgsz 640, batch 16 | seed 445 | baselines=True

# %% [markdown]
# ## 2. Environment
# Only `ultralytics` is needed here — the weight surgery mirrors `ssl-detection-lab`'s own
# backbone definition (`model[: len(yaml['backbone'])]`) using plain PyTorch state-dicts, so
# 3b stays light and version-independent.

# %%
# %pip install -q -U ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.1 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from copy import deepcopy
import json, random, shutil, time, os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from PIL import Image
from tqdm.auto import tqdm
import torch
from ultralytics import YOLO
import ultralytics

random.seed(PARTB_SEED); np.random.seed(PARTB_SEED); torch.manual_seed(PARTB_SEED)
DEVICE = 0 if torch.cuda.is_available() else "cpu"
plt.rcParams.update({"figure.dpi": 125, "font.size": 11})
for d in (DATA_ROOT, RUN_PROJECT, DOWNSTREAM_DIR, CKPT_OUT):
    Path(d).mkdir(parents=True, exist_ok=True)
print("ultralytics:", ultralytics.__version__, "| torch:", torch.__version__,
      "| GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ultralytics: 8.4.114 | torch: 2.10.0+cu128 | GPU: Tesla T4

# %% [markdown]
# ## 3. Locate the Hand-off Artifacts
# Finds the 3a checkpoint + shared partition manifest, Notebook 1's labelled images, and
# (optionally) the Part A checkpoint — with loud failures naming exactly what to attach.

# %%
def find_file(pattern, manual, what, required=True, depth=5):
    if manual is not None:
        p = Path(manual)
        if p.exists():
            return p
        raise FileNotFoundError(f"Manual {what} path does not exist: {p}")
    base, stack = Path("/kaggle/input"), [(Path("/kaggle/input"), 0)]
    while stack:
        d, dep = stack.pop()
        try:
            for c in d.iterdir():
                if c.is_file() and c.name == pattern:
                    return c
                if c.is_dir() and dep < depth:
                    stack.append((c, dep + 1))
        except (PermissionError, OSError):
            pass
    if required:
        raise FileNotFoundError(f"{what} ({pattern}) not found under /kaggle/input — "
                                "attach the input listed in Section 0.")
    return None

def find_nb1_root():
    if NB1_DIR_MANUAL is not None:
        p = Path(NB1_DIR_MANUAL)
        assert (p / "train" / "images").exists(), f"not the NB1 output: {p}"
        return p
    stack = [(Path("/kaggle/input"), 0)]
    while stack:
        d, dep = stack.pop()
        if d.name == "visiodect_yolo" and (d / "train" / "images").exists():
            return d
        if dep < 4:
            try:
                stack += [(c, dep + 1) for c in d.iterdir() if c.is_dir()]
            except (PermissionError, OSError):
                pass
    raise FileNotFoundError("Attach Part A Notebook 1's OUTPUT (visiodect_yolo/).")

SSL_CKPT      = find_file("ijepa_yolo26s_backbone.pt", CKPT_MANUAL, "I-JEPA YOLO checkpoint")
PARTITION_CSV = find_file("partB_partition.csv", PARTITION_MANUAL, "Part B partition manifest")
NB1_ROOT      = find_nb1_root()
PARTA_CKPT    = find_file("yolov26s_best.pt", PARTA_CKPT_MANUAL,
                          "Part A reference checkpoint", required=False)
summary_3a = find_file("ijepa_pretrain_summary.json", None, "3a summary", required=False)
if summary_3a:
    s3a = json.loads(Path(summary_3a).read_text())
    print("3a pretraining context:", {k: s3a[k] for k in
          ("method", "epochs", "image_size", "ssl_pool_images", "best_loss", "train_minutes")
          if k in s3a})
print("SSL checkpoint :", SSL_CKPT)
print("Partition CSV  :", PARTITION_CSV)
print("NB1 labels root:", NB1_ROOT)
print("Part A ckpt    :", PARTA_CKPT or "not attached (reference section will skip)")
# Out:
# 3a pretraining context: {'method': 'ijepa', 'epochs': 50, 'image_size': 224, 'ssl_pool_images': 16483, 'best_loss': 0.016039776122559187, 'train_minutes': 167.7}
# SSL checkpoint : /kaggle/input/notebooks/ahnafahmed11/partb-notebook3a-i-jepa-self-supervisedpretraining/ijepa_yolo26s_backbone.pt
# Partition CSV  : /kaggle/input/notebooks/ahnafahmed11/partb-notebook3a-i-jepa-self-supervisedpretraining/partB_partition.csv
# NB1 labels root: /kaggle/input/notebooks/ahnafahmed11/cse445notebook1-datasetexploration-preprocessing/visiodect_yolo
# Part A ckpt    : /kaggle/input/notebooks/ahnafahmed11/cse445notebook4-yolov26trainevaluate-erroranalysis/checkpoints/yolov26s_best.pt

# %% [markdown]
# ## 4. Subset Builder —
# Rebuilds **D₀.₂** from the shared manifest's `pool_rank` (`rank < 0.20·N` — nested by
# construction with the bonus budgets), restores the annotations from Notebook 1, prints
# **image and instance counts**, and re-verifies **disjointness against test and validation**
# by filename intersection. The materialised YOLO dataset uses the partition's val/test —
# never Part A's splits.

# %%
partition = pd.read_csv(PARTITION_CSV)
N = len(partition)
n20 = round(RHO * N)
sub = {
    "train": partition[(partition.partition == "ssl_pool") & (partition.pool_rank < n20)],
    "val":   partition[partition.partition == "val"],
    "test":  partition[partition.partition == "test"],
}
print(f"Partition manifest: {N:,} images | rho={RHO} -> {n20:,} labelled fine-tune images "
      f"(pool_rank < {n20:,})")

# mandated disjointness re-verification in THIS notebook
tr, va, te = (set(sub[k].filename) for k in ("train", "val", "test"))
assert not (tr & va) and not (tr & te) and not (va & te)
assert len(tr) == n20
print("[OK] Disjointness verified by filename intersection: "
      "train20 ∩ val = 0, train20 ∩ test = 0, val ∩ test = 0")

CLASS_NAMES = ["Anafi", "DJI_FPV", "DJI_Phantom", "EFT_E410S", "Mavic_Air", "Mavic_Enterprise"]

def label_path_for(img_path):
    return Path(str(img_path).replace("/images/", "/labels/")).with_suffix(".txt")

def safe_link(src, dst):
    if dst.exists():
        return
    try:
        os.symlink(src, dst)
    except OSError:
        shutil.copy2(src, dst)

data_root = Path(DATA_ROOT)
if data_root.exists():
    shutil.rmtree(data_root)
counts = []
for split, frame in sub.items():
    (data_root / split / "images").mkdir(parents=True)
    (data_root / split / "labels").mkdir(parents=True)
    inst = 0
    for _, r in tqdm(frame.iterrows(), total=len(frame), desc=f"materialising {split}"):
        img = Path(r.source_path); lbl = label_path_for(img)
        assert lbl.exists(), f"missing label for {img.name} — wrong NB1 output attached?"
        safe_link(img, data_root / split / "images" / img.name)
        safe_link(lbl, data_root / split / "labels" / lbl.name)
        inst += sum(1 for ln in lbl.read_text().splitlines() if len(ln.split()) == 5)
    counts.append({"split": split, "images": len(frame), "instances": inst})
count_df = pd.DataFrame(counts)
display(count_df)

# per-class instance counts in the 20% subset (assignment: instance counts)
per_cls = {c: 0 for c in CLASS_NAMES}
for _, r in sub["train"].iterrows():
    for ln in label_path_for(Path(r.source_path)).read_text().splitlines():
        t = ln.split()
        if len(t) == 5:
            per_cls[CLASS_NAMES[int(t[0])]] += 1
print("20%-subset instances per class:", per_cls)

DATA_YAML = data_root / "data.yaml"
DATA_YAML.write_text(f"path: {data_root}\ntrain: train/images\nval: val/images\n"
                     f"test: test/images\nnc: {len(CLASS_NAMES)}\nnames: {CLASS_NAMES}\n")
print("data.yaml written ->", DATA_YAML)
# Out:
# Partition manifest: 20,603 images | rho=0.2 -> 4,121 labelled fine-tune images (pool_rank < 4,121)
# [OK] Disjointness verified by filename intersection: train20 ∩ val = 0, train20 ∩ test = 0, val ∩ test = 0
# materialising train:   0%|          | 0/4121 [00:00<?, ?it/s]
# materialising val:   0%|          | 0/2060 [00:00<?, ?it/s]
# materialising test:   0%|          | 0/2060 [00:00<?, ?it/s]
#    split  images  instances
# 0  train    4121       4122
# 1    val    2060       2060
# 2   test    2060       2060
# 20%-subset instances per class: {'Anafi': 683, 'DJI_FPV': 694, 'DJI_Phantom': 662, 'EFT_E410S': 669, 'Mavic_Air': 704, 'Mavic_Enterprise': 710}
# data.yaml written -> /kaggle/working/partB_data/data.yaml

# %% [markdown]
# ## 5. Weight Surgery + Mandatory Layer-Mapping Report —
# `ssl-detection-lab` defines the pretrained encoder as **`model[: len(yaml["backbone"])]`**
# (its `YOLOBackboneEncoder` wraps exactly those modules by reference), so the surgery below
# mirrors the package's own boundary: a **fresh** YOLOv26-s is built (new random neck + head),
# and only the backbone-module keys are copied from the 3a checkpoint. The mandatory report
# prints, per top-level module: index, layer type, parameter count, and **source (I-JEPA SSL
# vs random init)** — followed by tensor-checksum proof that the surgically merged weights are
# the ones training actually starts from.

# %%
ssl_yolo   = YOLO(str(SSL_CKPT))            # 3a checkpoint: SSL backbone + 3a-random rest
fresh_yolo = YOLO(YOLO_ARCH)                # brand-new model: fresh random neck/head
BACKBONE_END = len(fresh_yolo.model.yaml["backbone"])   # == ssldet's boundary

ssl_sd, fresh_sd = ssl_yolo.model.state_dict(), fresh_yolo.model.state_dict()
assert set(ssl_sd) == set(fresh_sd), "architecture mismatch between 3a checkpoint and yaml!"

merged, n_ssl_params = {}, 0
for k, v in fresh_sd.items():
    idx = int(k.split(".")[1]) if k.startswith("model.") else -1
    from_ssl = 0 <= idx < BACKBONE_END
    merged[k] = ssl_sd[k].clone() if from_ssl else v
    if from_ssl:
        n_ssl_params += v.numel()
fresh_yolo.model.load_state_dict(merged, strict=True)

# ---- the mandatory mapping report -------------------------------------------
rows = []
for i, m in enumerate(fresh_yolo.model.model):
    rows.append({"module": f"model.{i}", "layer": type(m).__name__,
                 "params": sum(p.numel() for p in m.parameters()),
                 "initialised from": "I-JEPA SSL checkpoint" if i < BACKBONE_END
                                     else "random (fresh)"})
mapping = pd.DataFrame(rows)
display(mapping)
total = sum(r["params"] for r in rows)
print(f"Backbone boundary: modules 0..{BACKBONE_END-1} (len(yaml['backbone']) — identical "
      f"to ssl-detection-lab's YOLOBackboneEncoder)")
print(f"SSL-initialised parameters: {n_ssl_params/1e6:.2f} M of {total/1e6:.2f} M "
      f"({n_ssl_params/total:.1%}); neck + Detect head remain randomly initialised.")

# ---- save in ultralytics checkpoint format and PROVE the weights survive -----
torch.save({"model": deepcopy(fresh_yolo.model), "train_args": {}}, SURGERY_CKPT)
reloaded = YOLO(SURGERY_CKPT)
bb_key  = next(k for k in ssl_sd if k.startswith("model.0.") and ssl_sd[k].ndim > 1)
hd_key  = next(k for k in fresh_sd
               if k.startswith(f"model.{len(fresh_yolo.model.model)-1}.") and fresh_sd[k].ndim > 1)
r_sd = reloaded.model.state_dict()
print("proof — backbone tensor equals SSL checkpoint:",
      bool(torch.equal(r_sd[bb_key].float(), ssl_sd[bb_key].float())))
print("proof — head tensor equals fresh random init  :",
      bool(torch.equal(r_sd[hd_key].float(), fresh_sd[hd_key].float())))
del ssl_yolo, fresh_yolo, reloaded, merged, ssl_sd, fresh_sd
torch.cuda.empty_cache()
# Out:
#       module     layer   params       initialised from
# 0    model.0      Conv      928  I-JEPA SSL checkpoint
# 1    model.1      Conv    18560  I-JEPA SSL checkpoint
# 2    model.2      C3k2    26080  I-JEPA SSL checkpoint
# 3    model.3      Conv   147712  I-JEPA SSL checkpoint
# 4    model.4      C3k2   103360  I-JEPA SSL checkpoint
# 5    model.5      Conv   590336  I-JEPA SSL checkpoint
# 6    model.6      C3k2   346112  I-JEPA SSL checkpoint
# 7    model.7      Conv  1180672  I-JEPA SSL checkpoint
# 8    model.8      C3k2  1380352  I-JEPA SSL checkpoint
# 9    model.9      SPPF   656896  I-JEPA SSL checkpoint
# 10  model.10     C2PSA   990976  I-JEPA SSL checkpoint
# 11  model.11  Upsample        0         random (fresh)
# 12  model.12    Concat        0         random (fresh)
# 13  model.13      C3k2   477184         random (fresh)
# 14  model.14  Upsample        0         random (fresh)
# 15  model.15    Concat        0         random (fresh)
# 16  model.16      C3k2   136192         random (fresh)
# 17  model.17      Conv   147712         random (fresh)
# 18  model.18    Concat        0         random (fresh)
# 19  model.19      C3k2   378880         random (fresh)
# 20  model.20      Conv   590336         random (fresh)
# 21  model.21    Concat        0         random (fresh)
# 22  model.22      C3k2  1843712         random (fresh)
# 23  model.23    Detect   993784         random (fresh)
# Backbone boundary: modules 0..10 (len(yaml['backbone']) — identical to ssl-detection-lab's YOLOBackboneEncoder)
# SSL-initialised parameters: 5.46 M of 10.01 M (54.5%); neck + Detect head remain randomly initialised.
# proof — backbone tensor equals SSL checkpoint: True
# proof — head tensor equals fresh random init  : True

# %% [markdown]
# ## 6. Fine-Tuning Runs —
# One helper enforces the **frozen protocol** for every run — the only argument that differs
# is the initialisation. Budget note (measured, Part A): YOLOv26-s = 322.6 min / 50 epochs /
# 14,422 images → ≈ 92 min per run at 4,121 images → ≈ 4.6 h for all three.

# %%
def finetune_and_eval(init_name, weights):
    """Train with the frozen protocol from `weights`; return metrics record."""
    run_name = f"{init_name}_rho{int(RHO*100)}"
    t0 = time.time()
    model = YOLO(weights)
    model.train(data=str(DATA_YAML), epochs=EPOCHS, patience=PATIENCE, imgsz=IMGSZ,
                batch=BATCH, workers=WORKERS, device=DEVICE, seed=PARTB_SEED,
                project=RUN_PROJECT, name=run_name, exist_ok=True,
                optimizer=OPTIMIZER, lr0=LR0, warmup_epochs=WARMUP_EPOCHS,
                close_mosaic=CLOSE_MOSAIC, fliplr=FLIPLR, flipud=FLIPUD, degrees=DEGREES,
                hsv_h=HSV_H, hsv_s=HSV_S, hsv_v=HSV_V, mixup=MIXUP, copy_paste=COPY_PASTE,
                plots=True, verbose=False)
    minutes = (time.time() - t0) / 60
    run_dir = Path(RUN_PROJECT) / run_name
    best = run_dir / "weights" / "best.pt"
    best = best if best.exists() else run_dir / "weights" / "last.pt"
    ckpt_out = Path(CKPT_OUT) / f"partB_{init_name}_rho{int(RHO*100)}_best.pt"
    shutil.copy2(best, ckpt_out)

    model = YOLO(str(best))
    rec = {"init": init_name, "rho": RHO, "epochs": EPOCHS,
           "train_minutes": round(minutes, 1)}
    for split in ("val", "test"):
        m = model.val(data=str(DATA_YAML), split=split, imgsz=IMGSZ, batch=BATCH,
                      conf=0.001, iou=IOU_NMS, device=DEVICE, plots=(split == "test"),
                      project=f"{WORK_ROOT}/evaluation", name=f"{run_name}_{split}",
                      exist_ok=True, verbose=False)
        rec |= {f"{split}_precision": round(float(m.box.mp), 4),
                f"{split}_recall":    round(float(m.box.mr), 4),
                f"{split}_mAP50":     round(float(m.box.map50), 4),
                f"{split}_mAP50_95":  round(float(m.box.map), 4)}
    try:  # best epoch from results.csv
        res = pd.read_csv(run_dir / "results.csv"); res.columns = [c.strip() for c in res.columns]
        rec["best_epoch"] = int(res.loc[res["metrics/mAP50-95(B)"].idxmax(), "epoch"])
    except Exception:
        rec["best_epoch"] = None
    rec["checkpoint"] = str(ckpt_out)
    Path(DOWNSTREAM_DIR, f"{init_name}.json").write_text(json.dumps(rec, indent=2))
    print(f"[{init_name}] {minutes:.0f} min | test mAP50-95 {rec['test_mAP50_95']} "
          f"| best epoch {rec['best_epoch']} | saved {ckpt_out.name}")
    torch.cuda.empty_cache()
    return rec

results = {}
results["ijepa"] = finetune_and_eval("ijepa", SURGERY_CKPT)
# Out:
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/partB_data/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/ijepa_surgery_init.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=ijepa_rho20, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs_partB, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs_partB/ijepa_rho20, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=445, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.1MB/s 0.1s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    477184  ultralytics.nn.modules.block.C3k2            [768, 256, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1843712  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    936508  ultralytics.nn.modules.head.Detect           [6, 1, True, [128, 256, 512]]
# YOLO26s summary: 260 layers, 9,952,508 parameters, 9,952,508 gradients, 22.8 GFLOPs
#
# Transferred 696/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 61.2MB/s 0.1s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.3±0.3 ms, read: 9.6±5.2 MB/s, size: 91.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/partB_data/train/labels... 4121 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4121/4121 395.8it/s 10.4s
# train: New cache created: /kaggle/working/partB_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.2±0.2 ms, read: 15.9±7.3 MB/s, size: 85.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/partB_data/val/labels... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 399.7it/s 5.2s
# val: New cache created: /kaggle/working/partB_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs_partB/ijepa_rho20/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs_partB/ijepa_rho20
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        1/50      4.83G      3.034       12.4   0.007888         13        640: 100% ━━━━━━━━━━━━ 258/258 2.6it/s 1:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 2.4it/s 27.2s
#                    all       2060       2060      0.259      0.316      0.205       0.08
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        2/50      6.27G      2.199      4.766   0.003959         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.341      0.438      0.367      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        3/50      6.27G      2.028      2.563   0.003533         13        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.587      0.649      0.663      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        4/50      6.27G      1.957       1.84   0.003374         16        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.485      0.526      0.563      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        5/50      6.27G      1.878      1.523   0.003151         20        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.721      0.742        0.8      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        6/50      6.27G      1.826      1.345   0.003043         21        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060       0.72      0.756      0.792      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        7/50      6.27G      1.794      1.208   0.002918         26        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060       0.64      0.806      0.807       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        8/50      6.27G      1.784       1.13   0.002971         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.779       0.77      0.851      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        9/50      6.27G      1.778      1.075   0.002949         20        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.823      0.789      0.872      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       10/50      6.27G      1.752      1.043   0.002916         13        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.807      0.821      0.875      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       11/50      6.27G      1.736       1.01   0.002814         20        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.4s
#                    all       2060       2060      0.817      0.794      0.877      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       12/50      6.27G      1.713     0.9619   0.002763         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.818      0.822      0.887        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       13/50      6.27G      1.704     0.9366   0.002767         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.793      0.814       0.89      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       14/50      6.27G      1.701     0.9339   0.002757         15        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.2it/s 12.4s
#                    all       2060       2060      0.848       0.85      0.909      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       15/50      6.27G      1.719     0.8966   0.002769         23        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.824       0.85      0.905      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       16/50      6.27G      1.676     0.8774   0.002693         16        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.886      0.877      0.934      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       17/50      6.27G      1.661     0.8525    0.00269         10        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060      0.853      0.864      0.924      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       18/50      6.27G      1.632     0.8301   0.002564         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060      0.835      0.808      0.883      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       19/50      6.27G       1.65      0.842    0.00267         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.2s
#                    all       2060       2060       0.91      0.845      0.928      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       20/50      6.27G      1.636     0.7844   0.002626         11        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.2s
#                    all       2060       2060       0.85      0.872      0.921      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       21/50      6.27G      1.645     0.7975   0.002629         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.874      0.831      0.909      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       22/50      6.27G      1.634     0.7834   0.002599         19        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060      0.895       0.87      0.935      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       23/50      6.27G      1.603     0.7688   0.002584         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.897       0.89      0.941      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       24/50      6.27G      1.603       0.77   0.002529         12        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 11.9s
#                    all       2060       2060      0.902      0.876      0.938      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       25/50      6.27G      1.587      0.736   0.002458         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.885      0.895      0.947      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       26/50      6.27G      1.607     0.7315    0.00249         12        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.2s
#                    all       2060       2060      0.913      0.889      0.945      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       27/50      6.27G      1.592     0.7061   0.002476         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.2s
#                    all       2060       2060      0.917      0.892      0.948      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       28/50      6.27G      1.589     0.7179   0.002512         15        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060       0.92      0.896      0.954      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       29/50      6.27G      1.587     0.7122   0.002508         18        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.907      0.878       0.95      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       30/50      6.27G      1.568     0.6902   0.002474         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.913      0.912      0.965      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       31/50      6.27G      1.582     0.6965   0.002464         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.895      0.917      0.959      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       32/50      6.27G       1.55     0.6882   0.002411         18        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.928      0.902      0.963      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       33/50      6.27G      1.558     0.6717   0.002459         16        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.915      0.927       0.97      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       34/50      6.27G      1.527     0.6474   0.002394         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060      0.911      0.915      0.958      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       35/50      6.27G      1.546     0.6637   0.002409         21        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.911      0.917      0.961      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       36/50      6.27G      1.551     0.6541   0.002409         18        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060       0.93      0.926      0.966      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       37/50      6.27G      1.513      0.645   0.002361         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.928      0.923       0.97      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       38/50      6.27G      1.533     0.6405   0.002403         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.917      0.932      0.965      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       39/50      6.27G      1.511      0.631   0.002306         13        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.926      0.929      0.968      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       40/50      6.27G      1.498     0.6122   0.002347         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.935      0.939      0.972      0.593
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       41/50      6.27G      1.427     0.5565   0.002573          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060       0.91       0.92      0.964      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       42/50      6.27G      1.424      0.533    0.00253          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.7it/s 11.5s
#                    all       2060       2060      0.932      0.922      0.971      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       43/50      6.27G      1.424     0.5263   0.002509          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060       0.94      0.935      0.973      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       44/50      6.27G      1.414     0.5102   0.002514          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.951      0.944      0.978      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       45/50      6.27G       1.41     0.5171   0.002503          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.7s
#                    all       2060       2060      0.939      0.943      0.972      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       46/50      6.27G      1.419     0.5088     0.0025          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.7it/s 11.5s
#                    all       2060       2060       0.94      0.936      0.975        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       47/50      6.27G      1.385     0.5091   0.002479          8        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.5s
#                    all       2060       2060      0.942      0.943      0.977      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       48/50      6.27G      1.397     0.4986   0.002448          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.7it/s 11.5s
#                    all       2060       2060      0.947      0.943      0.977      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       49/50      6.27G      1.385     0.4958   0.002453          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.7it/s 11.5s
#                    all       2060       2060      0.955      0.943      0.979      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       50/50      6.27G      1.374     0.4922   0.002412          9        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.7it/s 11.4s
#                    all       2060       2060      0.951      0.941      0.978      0.605
#
# 50 epochs completed in 1.287 hours.
# Optimizer stripped from /kaggle/working/runs_partB/ijepa_rho20/weights/last.pt, 20.3MB
# Optimizer stripped from /kaggle/working/runs_partB/ijepa_rho20/weights/best.pt, 20.3MB
#
# Validating /kaggle/working/runs_partB/ijepa_rho20/weights/best.pt...
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.942      0.942      0.977      0.605
# Speed: 0.1ms preprocess, 2.5ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/runs_partB/ijepa_rho20
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 143.5±73.1 MB/s, size: 95.6 KB)
# val: Scanning /kaggle/working/partB_data/val/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 960.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 8.9it/s 14.6s
#                    all       2060       2060      0.943      0.943      0.977      0.605
# Speed: 0.5ms preprocess, 4.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.1±0.2 ms, read: 22.2±12.2 MB/s, size: 127.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/partB_data/test/labels... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 265.6it/s 7.8s
# val: New cache created: /kaggle/working/partB_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 7.6it/s 17.1s
#                    all       2060       2060       0.93      0.935      0.974      0.608
# Speed: 0.5ms preprocess, 4.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/evaluation/ijepa_rho20_test
# [ijepa] 79 min | test mAP50-95 0.6085 | best epoch 47 | saved partB_ijepa_rho20_best.pt

# %% [markdown]
# ### 6.1 Demo inference on one validation image
# *(The full evaluation above ran as part of the helper; this cell shows the mandated
# single-image sanity check with the fine-tuned I-JEPA detector.)*

# %%
ijepa_best = YOLO(results["ijepa"]["checkpoint"])
demo_img = sorted((Path(DATA_ROOT) / "val" / "images").iterdir())[0]
res = ijepa_best.predict(str(demo_img), imgsz=IMGSZ, conf=CONF_EVAL, device=DEVICE,
                         verbose=False)[0]
im = np.array(Image.open(demo_img).convert("RGB")); H, W = im.shape[:2]
fig, ax = plt.subplots(figsize=(10, 6)); ax.imshow(im); ax.set_axis_off()
lbl = Path(str(demo_img).replace("/images/", "/labels/")).with_suffix(".txt")
for ln in lbl.read_text().splitlines():
    c, cx, cy, w, h = map(float, ln.split())
    ax.add_patch(mpatches.Rectangle(((cx-w/2)*W, (cy-h/2)*H), w*W, h*H,
                                    fill=False, edgecolor="lime", lw=2.2))
if res.boxes is not None:
    for b, c, s in zip(res.boxes.xyxy.cpu().numpy(),
                       res.boxes.cls.cpu().numpy().astype(int),
                       res.boxes.conf.cpu().numpy()):
        ax.add_patch(mpatches.Rectangle((b[0], b[1]), b[2]-b[0], b[3]-b[1],
                                        fill=False, edgecolor="red", lw=2, linestyle="--"))
        ax.text(b[0], b[1]-5, f"{CLASS_NAMES[int(c)]} {s:.2f}", color="red", fontsize=10)
ax.set_title(f"Demo: I-JEPA@20% on validation image {demo_img.name} "
             "(GT green, prediction red)")
plt.tight_layout(); plt.show()

# %%
# ---- training curves + PR curve for the I-JEPA run --------------------------
run_dir = Path(RUN_PROJECT) / f"ijepa_rho{int(RHO*100)}"
res = pd.read_csv(run_dir / "results.csv"); res.columns = [c.strip() for c in res.columns]
fig, ax = plt.subplots(1, 2, figsize=(16, 5))
for k, lab in [("train/box_loss", "box"), ("train/cls_loss", "cls"), ("train/dfl_loss", "dfl")]:
    if k in res: ax[0].plot(res.epoch, res[k], label=lab)
ax[0].set_title("I-JEPA@20% training losses"); ax[0].set_xlabel("epoch"); ax[0].legend()
for k, lab in [("metrics/mAP50(B)", "val mAP50"), ("metrics/mAP50-95(B)", "val mAP50-95")]:
    if k in res: ax[1].plot(res.epoch, res[k], label=lab)
ax[1].set_title("Validation mAP"); ax[1].set_xlabel("epoch"); ax[1].legend()
plt.tight_layout(); plt.savefig(f"{WORK_ROOT}/ijepa20_curves.png", dpi=150,
                                bbox_inches="tight"); plt.show()

for cand in ["BoxPR_curve.png", "PR_curve.png"]:
    p = Path(f"{WORK_ROOT}/evaluation") / f"ijepa_rho{int(RHO*100)}_test" / cand
    if p.exists():
        plt.figure(figsize=(9, 7)); plt.imshow(plt.imread(p)); plt.axis("off")
        plt.title("PR curve — I-JEPA@20% on the 10% test holdout"); plt.show()
        break

# %% [markdown]
# ## 7. Baselines at the Same ρ —
# (a) **random init** (`yolo26s.yaml`) and (b) **COCO-pretrained** (`yolo26s.pt`), trained with
# the byte-identical protocol. These anchor the value each SSL method adds. Run **once here**;
# Notebooks 1b/2b/4b attach this output and set `RUN_BASELINES = False`.

# %%
if RUN_BASELINES:
    results["random"] = finetune_and_eval("random", YOLO_ARCH)
    results["coco"]   = finetune_and_eval("coco",   COCO_WEIGHTS)
else:
    print("RUN_BASELINES=False — baseline JSONs are expected from an attached "
          "notebook output and will be merged in Section 8.")
# Out:
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/partB_data/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=random_rho20, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs_partB, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs_partB/random_rho20, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=445, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    477184  ultralytics.nn.modules.block.C3k2            [768, 256, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1843712  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    936508  ultralytics.nn.modules.head.Detect           [6, 1, True, [128, 256, 512]]
# YOLO26s summary: 260 layers, 9,952,508 parameters, 9,952,508 gradients, 22.8 GFLOPs
#
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 127.7±101.4 MB/s, size: 79.7 KB)
# train: Scanning /kaggle/working/partB_data/train/labels.cache... 4121 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4121/4121 1.6Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 166.2±58.6 MB/s, size: 91.4 KB)
# val: Scanning /kaggle/working/partB_data/val/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 141.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs_partB/random_rho20/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs_partB/random_rho20
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        1/50      5.11G       3.22      12.63   0.008712         13        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.136      0.187     0.0856     0.0301
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        2/50      6.54G      2.215      3.384   0.004054         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060        0.3      0.505      0.372      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        3/50      6.54G      2.034       2.12   0.003557         13        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060        0.4      0.432       0.39      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        4/50      6.54G      1.969      1.783   0.003377         16        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060       0.54      0.616      0.614      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        5/50      6.54G      1.934      1.614   0.003276         20        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.616      0.645      0.686      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        6/50      6.54G      1.845      1.454   0.003088         21        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060       0.69      0.686      0.749      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        7/50      6.54G      1.848      1.346   0.003005         26        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.608      0.667       0.66      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        8/50      6.54G      1.818      1.269   0.003021         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.674      0.715       0.77       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        9/50      6.54G      1.791      1.196   0.002979         20        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.7s
#                    all       2060       2060      0.743      0.762      0.823      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       10/50      6.54G      1.764      1.156   0.002928         13        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.755      0.706      0.819      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       11/50      6.54G      1.745      1.105   0.002826         20        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.788      0.759      0.836      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       12/50      6.54G      1.748      1.063   0.002825         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.729      0.692      0.782      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       13/50      6.54G      1.707      1.021   0.002771         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.662      0.681      0.727      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       14/50      6.54G      1.746      1.059    0.00284         15        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.723      0.564      0.724      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       15/50      6.54G      1.721      1.021   0.002767         23        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.812      0.815      0.882      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       16/50      6.54G      1.687     0.9663   0.002716         16        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.801      0.823      0.882      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       17/50      6.54G      1.694     0.9388   0.002755         10        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.767      0.807      0.876      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       18/50      6.54G      1.661     0.9135   0.002623         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.831      0.843      0.904      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       19/50      6.54G      1.661     0.9334   0.002676         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.818      0.828      0.893      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       20/50      6.54G      1.628     0.8779   0.002593         11        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.846      0.801      0.895      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       21/50      6.54G      1.641     0.8753   0.002617         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.7s
#                    all       2060       2060      0.874      0.841      0.917       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       22/50      6.54G      1.635     0.8827   0.002612         19        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.846      0.843      0.908      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       23/50      6.54G      1.613     0.8342   0.002614         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.885      0.858      0.927      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       24/50      6.54G      1.615     0.8384    0.00255         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.838       0.85      0.914      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       25/50      6.54G      1.597     0.8009   0.002486         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.845       0.86      0.922       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       26/50      6.54G      1.615     0.8057   0.002512         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.879       0.86      0.926      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       27/50      6.54G       1.58     0.7849   0.002478         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.879      0.842      0.923      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       28/50      6.54G      1.593     0.7874    0.00253         15        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.886       0.88       0.94       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       29/50      6.54G      1.607     0.7684   0.002542         18        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.903      0.874      0.938      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       30/50      6.54G      1.574       0.76   0.002481         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.888      0.881      0.939      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       31/50      6.54G      1.589      0.765   0.002469         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.906      0.891      0.948      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       32/50      6.54G      1.568     0.7484   0.002436         18        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060        0.9      0.881      0.944      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       33/50      6.54G      1.562     0.7501   0.002466         16        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.6s
#                    all       2060       2060      0.878      0.874      0.935      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       34/50      6.54G      1.555     0.7175    0.00245         14        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.905      0.896      0.949      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       35/50      6.54G      1.549     0.7243   0.002418         21        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.899      0.885      0.943      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       36/50      6.54G      1.556     0.7316   0.002428         18        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.8s
#                    all       2060       2060      0.904      0.894      0.949      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       37/50      6.54G      1.522     0.7073   0.002379         12        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.907      0.905      0.956      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       38/50      6.54G      1.537      0.698   0.002414         12        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.2s
#                    all       2060       2060      0.886      0.875      0.942      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       39/50      6.54G      1.526     0.7073   0.002341         13        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.2it/s 12.5s
#                    all       2060       2060      0.909      0.897      0.953       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       40/50      6.54G      1.519     0.6834   0.002389         12        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.908      0.902      0.956      0.582
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       41/50      6.54G      1.451     0.6186   0.002614          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.914      0.905      0.957       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       42/50      6.54G      1.446     0.5978   0.002577          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 12.9s
#                    all       2060       2060      0.919      0.901      0.956      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       43/50      6.54G      1.442     0.5914   0.002539          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.9s
#                    all       2060       2060      0.909      0.907      0.962      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       44/50      6.54G      1.429     0.5773   0.002553          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 12.9s
#                    all       2060       2060      0.919      0.914      0.964      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       45/50      6.54G      1.416     0.5765   0.002503          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.8s
#                    all       2060       2060      0.909      0.915       0.96      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       46/50      6.54G      1.413     0.5769   0.002497          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.7s
#                    all       2060       2060      0.921      0.915      0.963      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       47/50      6.54G      1.403     0.5627    0.00252          8        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.2it/s 12.6s
#                    all       2060       2060       0.92       0.92      0.965      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       48/50      6.54G      1.411     0.5616   0.002478          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.8s
#                    all       2060       2060      0.922      0.916      0.965      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       49/50      6.54G      1.388     0.5618   0.002456          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.6s
#                    all       2060       2060      0.937       0.92      0.968      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       50/50      6.54G      1.394     0.5541   0.002454          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.7s
#                    all       2060       2060      0.936      0.919      0.969      0.595
#
# 50 epochs completed in 1.281 hours.
# Optimizer stripped from /kaggle/working/runs_partB/random_rho20/weights/last.pt, 20.3MB
# Optimizer stripped from /kaggle/working/runs_partB/random_rho20/weights/best.pt, 20.3MB
#
# Validating /kaggle/working/runs_partB/random_rho20/weights/best.pt...
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.4s
#                    all       2060       2060      0.937       0.92      0.968      0.596
# Speed: 0.1ms preprocess, 2.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /kaggle/working/runs_partB/random_rho20
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 98.5±62.0 MB/s, size: 91.8 KB)
# val: Scanning /kaggle/working/partB_data/val/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 664.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 8.3it/s 15.6s
#                    all       2060       2060      0.937       0.92      0.968      0.596
# Speed: 0.5ms preprocess, 4.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 217.4±97.2 MB/s, size: 139.4 KB)
# val: Scanning /kaggle/working/partB_data/test/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 785.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 7.0it/s 18.4s
#                    all       2060       2060       0.92      0.901      0.956      0.593
# Speed: 0.5ms preprocess, 4.7ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /kaggle/working/evaluation/random_rho20_test
# [random] 77 min | test mAP50-95 0.5928 | best epoch 49 | saved partB_random_rho20_best.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26s.pt to 'yolo26s.pt': 100% ━━━━━━━━━━━━ 19.5MB 137.3MB/s 0.1s
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/partB_data/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=coco_rho20, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs_partB, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs_partB/coco_rho20, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=445, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    477184  ultralytics.nn.modules.block.C3k2            [768, 256, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1843712  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    936508  ultralytics.nn.modules.head.Detect           [6, 1, True, [128, 256, 512]]
# YOLO26s summary: 260 layers, 9,952,508 parameters, 9,952,508 gradients, 22.8 GFLOPs
#
# Transferred 696/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 165.5±148.5 MB/s, size: 79.7 KB)
# train: Scanning /kaggle/working/partB_data/train/labels.cache... 4121 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4121/4121 236.8Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 94.0±41.7 MB/s, size: 91.4 KB)
# val: Scanning /kaggle/working/partB_data/val/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 113.7Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs_partB/coco_rho20/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs_partB/coco_rho20
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        1/50      5.09G      1.804      8.147   0.002903         13        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.3s
#                    all       2060       2060      0.712      0.725      0.765       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        2/50      6.51G       1.74      1.356   0.002765         17        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.715      0.765      0.787      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        3/50      6.51G      1.731       0.96   0.002762         13        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.811      0.772      0.841      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        4/50      6.51G      1.698     0.8428   0.002713         16        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.4s
#                    all       2060       2060      0.894      0.875      0.927       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        5/50      6.51G      1.694     0.8186   0.002694         20        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.813       0.85      0.893      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        6/50      6.51G      1.651     0.7471   0.002623         21        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060       0.88       0.92      0.945      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        7/50      6.51G      1.636     0.7081   0.002537         26        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.2it/s 12.4s
#                    all       2060       2060      0.811      0.784      0.852      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        8/50      6.51G      1.636      0.703   0.002608         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.904      0.925      0.955      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        9/50      6.51G      1.599     0.6825   0.002551         20        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.916      0.924      0.958      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       10/50      6.51G      1.595      0.677   0.002557         13        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.922      0.925      0.962      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       11/50      6.51G      1.577     0.6271    0.00247         20        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.0s
#                    all       2060       2060      0.923      0.925      0.957      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       12/50      6.51G      1.569     0.6211   0.002429         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.7s
#                    all       2060       2060      0.919      0.909      0.945      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       13/50      6.51G      1.563     0.6207   0.002434         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.2s
#                    all       2060       2060      0.918      0.919      0.955      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       14/50      6.51G      1.562     0.6015   0.002445         15        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.4s
#                    all       2060       2060      0.921      0.928      0.961      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       15/50      6.51G       1.56     0.5974   0.002432         23        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 13.1s
#                    all       2060       2060      0.945      0.931      0.962      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       16/50      6.51G      1.536     0.5772   0.002407         16        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.2s
#                    all       2060       2060      0.958      0.939      0.967      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       17/50      6.51G      1.544     0.5684    0.00243         10        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.8it/s 13.4s
#                    all       2060       2060      0.931       0.94      0.969      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       18/50      6.51G      1.521     0.5564   0.002328         14        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.6s
#                    all       2060       2060      0.959       0.96       0.98      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       19/50      6.51G      1.512     0.5519   0.002374         17        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.8it/s 13.4s
#                    all       2060       2060      0.954      0.946      0.977      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       20/50      6.51G      1.512     0.5388   0.002347         11        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060      0.944      0.947      0.973      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       21/50      6.51G      1.518     0.5296   0.002361         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.3s
#                    all       2060       2060      0.958      0.958      0.979       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       22/50      6.51G      1.515     0.5252   0.002358         19        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.7s
#                    all       2060       2060      0.952      0.951      0.978      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       23/50      6.51G      1.501     0.4953   0.002371         12        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.4s
#                    all       2060       2060      0.955       0.96      0.981      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       24/50      6.51G      1.478      0.512    0.00229         12        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.2it/s 12.5s
#                    all       2060       2060      0.946      0.942      0.975      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       25/50      6.51G      1.458     0.5105   0.002225         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.7s
#                    all       2060       2060      0.955      0.956       0.98        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       26/50      6.51G      1.481     0.4887   0.002254         12        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 13.0s
#                    all       2060       2060      0.921      0.917      0.945      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       27/50      6.51G      1.454     0.4847   0.002224         17        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.7s
#                    all       2060       2060      0.885      0.787      0.845      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       28/50      6.51G      1.466     0.4837   0.002273         15        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.3it/s 12.2s
#                    all       2060       2060      0.963       0.96       0.98      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       29/50      6.51G      1.465     0.4862    0.00227         18        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.6it/s 11.7s
#                    all       2060       2060       0.97      0.967      0.986      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       30/50      6.51G      1.446     0.4717   0.002242         14        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.7it/s 11.3s
#                    all       2060       2060       0.97      0.964      0.983      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       31/50      6.51G      1.447     0.4827   0.002209         17        640: 100% ━━━━━━━━━━━━ 258/258 3.3it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060       0.98      0.971      0.989       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       32/50      6.51G      1.438     0.4676   0.002196         18        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.4s
#                    all       2060       2060      0.973      0.968      0.983      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       33/50      6.51G      1.429       0.46    0.00221         16        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.7it/s 13.9s
#                    all       2060       2060      0.972      0.973      0.984      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       34/50      6.51G      1.408     0.4483   0.002175         14        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.8it/s 13.6s
#                    all       2060       2060      0.975      0.972      0.983      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       35/50      6.51G      1.426     0.4492   0.002184         21        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.7s
#                    all       2060       2060      0.975      0.976      0.986      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       36/50      6.51G      1.408     0.4504   0.002142         18        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.5it/s 11.9s
#                    all       2060       2060      0.979      0.976      0.989      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       37/50      6.51G      1.386     0.4448   0.002126         12        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.2s
#                    all       2060       2060      0.978      0.978      0.989      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       38/50      6.51G      1.391     0.4234   0.002136         12        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.4it/s 12.1s
#                    all       2060       2060      0.977      0.976      0.991       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       39/50      6.51G      1.387     0.4321    0.00208         13        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.2s
#                    all       2060       2060      0.977      0.979      0.988      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       40/50      6.51G      1.385     0.4268   0.002136         12        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 12.9s
#                    all       2060       2060      0.978      0.981      0.988      0.616
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       41/50      6.51G      1.348      0.381   0.002403          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.8it/s 13.5s
#                    all       2060       2060      0.973      0.972      0.981      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       42/50      6.51G      1.333     0.3746   0.002349          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.7it/s 13.7s
#                    all       2060       2060      0.978      0.975      0.988      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       43/50      6.51G       1.32     0.3655   0.002295          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.8it/s 13.6s
#                    all       2060       2060      0.974      0.976      0.986      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       44/50      6.51G      1.319     0.3649   0.002324          9        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.8s
#                    all       2060       2060      0.978       0.98       0.99      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       45/50      6.51G      1.318     0.3761   0.002305          9        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.9it/s 13.2s
#                    all       2060       2060      0.975      0.979      0.987       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       46/50      6.51G      1.309     0.3654   0.002287          9        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 13.1s
#                    all       2060       2060      0.978      0.979      0.987      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       47/50      6.51G      1.293     0.3621   0.002291          8        640: 100% ━━━━━━━━━━━━ 258/258 3.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.7it/s 13.8s
#                    all       2060       2060      0.978       0.98      0.987      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       48/50      6.51G      1.302     0.3554    0.00226          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.8s
#                    all       2060       2060      0.979       0.98      0.988      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       49/50      6.51G      1.285     0.3557   0.002255          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.0it/s 13.1s
#                    all       2060       2060      0.978      0.979      0.986      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       50/50      6.51G      1.281      0.347   0.002235          9        640: 100% ━━━━━━━━━━━━ 258/258 3.2it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 5.1it/s 12.8s
#                    all       2060       2060      0.978      0.979      0.986      0.614
#
# 50 epochs completed in 1.326 hours.
# Optimizer stripped from /kaggle/working/runs_partB/coco_rho20/weights/last.pt, 20.3MB
# Optimizer stripped from /kaggle/working/runs_partB/coco_rho20/weights/best.pt, 20.3MB
#
# Validating /kaggle/working/runs_partB/coco_rho20/weights/best.pt...
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 65/65 4.8it/s 13.5s
#                    all       2060       2060      0.977      0.975      0.989       0.62
# Speed: 0.1ms preprocess, 2.3ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/runs_partB/coco_rho20
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 106.5±53.6 MB/s, size: 91.8 KB)
# val: Scanning /kaggle/working/partB_data/val/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 785.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 8.2it/s 15.7s
#                    all       2060       2060      0.977      0.975      0.989      0.622
# Speed: 0.5ms preprocess, 4.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 225.9±121.0 MB/s, size: 139.4 KB)
# val: Scanning /kaggle/working/partB_data/test/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 785.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 7.2it/s 17.9s
#                    all       2060       2060       0.97      0.973      0.984      0.622
# Speed: 0.6ms preprocess, 4.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/evaluation/coco_rho20_test
# [coco] 80 min | test mAP50-95 0.6224 | best epoch 36 | saved partB_coco_rho20_best.pt

# %% [markdown]
# ## 8. Optional — the 100%-Label Part A Reference
# Part A's YOLOv26-s checkpoint is attached, it is re-evaluated on the **new 10% test
# holdout** to give the upper reference line for every Part B plot. The assignment's caveat is
# printed with it: this reference is **optimistic**, because some holdout images were inside
# Part A's training split.

# %%
if RUN_REFERENCE and PARTA_CKPT is not None:
    m = YOLO(str(PARTA_CKPT)).val(data=str(DATA_YAML), split="test", imgsz=IMGSZ,
                                  batch=BATCH, conf=0.001, iou=IOU_NMS, device=DEVICE,
                                  plots=False, project=f"{WORK_ROOT}/evaluation",
                                  name="reference_100pct_test", exist_ok=True, verbose=False)
    ref = {"init": "partA_reference_100pct_labels",
           "test_precision": round(float(m.box.mp), 4),
           "test_recall": round(float(m.box.mr), 4),
           "test_mAP50": round(float(m.box.map50), 4),
           "test_mAP50_95": round(float(m.box.map), 4),
           "caveat": "optimistic — some of this holdout was in Part A's training split"}
    Path(DOWNSTREAM_DIR, "reference_100pct.json").write_text(json.dumps(ref, indent=2))
    print(json.dumps(ref, indent=2))
else:
    print("Part A checkpoint not attached — reference skipped (attach Notebook 4's "
          "output to enable; required for the report's dashed reference line).")
# Out:
# Ultralytics 8.4.114 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 137.3±77.2 MB/s, size: 69.2 KB)
# val: Scanning /kaggle/working/partB_data/test/labels.cache... 2060 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2060/2060 785.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 129/129 8.2it/s 15.8s
#                    all       2060       2060      0.985      0.986      0.992      0.668
# Speed: 0.5ms preprocess, 4.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# {
#   "init": "partA_reference_100pct_labels",
#   "test_precision": 0.9846,
#   "test_recall": 0.9865,
#   "test_mAP50": 0.9919,
#   "test_mAP50_95": 0.6678,
#   "caveat": "optimistic \u2014 some of this holdout was in Part A's training split"
# }

# %% [markdown]
# ## 9. Comparison — I-JEPA vs Random vs COCO at ρ = 0.20
# Merges every `partB_downstream/*.json` visible in the session (local runs plus any attached
# sibling notebook outputs), then prints the value-added deltas the report's §5.2 needs.

# %%
recs = {}
for j in list(Path(DOWNSTREAM_DIR).glob("*.json")):
    recs[j.stem] = json.loads(j.read_text())
stack = [(Path("/kaggle/input"), 0)]
while stack:
    d, dep = stack.pop()
    try:
        for c in d.iterdir():
            if c.is_file() and c.parent.name == "partB_downstream" and c.suffix == ".json":
                recs.setdefault(c.stem, json.loads(c.read_text()))
            elif c.is_dir() and dep < 5:
                stack.append((c, dep + 1))
    except (PermissionError, OSError):
        pass

comp = pd.DataFrame([r for k, r in recs.items() if k != "reference_100pct"])
cols = [c for c in ["init", "rho", "val_mAP50_95", "test_mAP50", "test_mAP50_95",
                    "test_precision", "test_recall", "best_epoch", "train_minutes"] if c in comp]
comp = comp[cols].sort_values("test_mAP50_95", ascending=False).reset_index(drop=True)
display(comp)

get = lambda n, k="test_mAP50_95": next((r[k] for r in recs.values() if r["init"] == n), None)
ij, rd, co = get("ijepa"), get("random"), get("coco")
ref = recs.get("reference_100pct", {}).get("test_mAP50_95")
if ij is not None and rd is not None:
    print(f"I-JEPA vs random init : {ij - rd:+.4f} mAP50-95  <- the SSL value-added at 20% labels")
if ij is not None and co is not None:
    print(f"I-JEPA vs COCO init   : {ij - co:+.4f} mAP50-95  <- SSL-on-domain vs generic supervised transfer")
if ij is not None and ref:
    print(f"I-JEPA@20% recovers {ij/ref:.1%} of the (optimistic) 100%-label Part A reference "
          f"({ij:.4f} / {ref:.4f})")
print("\nAfter 1b/2b/4b: rank all four methods by test mAP50-95 in this table; the winner's "
      "checkpoint is published for the tracking notebook (§4.2 note).")
# Out:
#      init  rho  val_mAP50_95  test_mAP50  test_mAP50_95  test_precision  \
# 0    coco  0.2        0.6217      0.9839         0.6224          0.9698
# 1   ijepa  0.2        0.6048      0.9737         0.6085          0.9296
# 2  random  0.2        0.5960      0.9559         0.5928          0.9197
#
#    test_recall  best_epoch  train_minutes
# 0       0.9731          36           80.2
# 1       0.9350          47           78.6
# 2       0.9012          49           77.5
# I-JEPA vs random init : +0.0157 mAP50-95  <- the SSL value-added at 20% labels
# I-JEPA vs COCO init   : -0.0139 mAP50-95  <- SSL-on-domain vs generic supervised transfer
# I-JEPA@20% recovers 91.1% of the (optimistic) 100%-label Part A reference (0.6085 / 0.6678)
#
# After 1b/2b/4b: rank all four methods by test mAP50-95 in this table; the winner's checkpoint is published for the tracking notebook (§4.2 note).

# %% [markdown]
# ## 10. Qualitative Predictions —
# A full test-split sweep with the I-JEPA@20% detector (predictions keyed by **input**
# filename — ultralytics rewrites `res.path` for list sources), greedily matched at IoU 0.5,
# then a panel of 4 successes + 4 failures with **full frame and 3× zoom** (Part A style —
# drones are ~59 px in 2400×1080 frames). The per-scenario miss rates print alongside, so the
# report can test whether the Part A failure signature (evening / Mavic_Enterprise / small)
# survives the 20% budget.

# %%
def iou_xyxy(a, b):
    ix1, iy1 = max(a[0], b[0]), max(a[1], b[1])
    ix2, iy2 = min(a[2], b[2]), min(a[3], b[3])
    inter = max(0, ix2-ix1) * max(0, iy2-iy1)
    return inter / ((a[2]-a[0])*(a[3]-a[1]) + (b[2]-b[0])*(b[3]-b[1]) - inter + 1e-9)

def gt_for(img_path):
    lbl = Path(str(img_path).replace("/images/", "/labels/")).with_suffix(".txt")
    with Image.open(img_path) as im:
        W, H = im.size
    out = []
    for ln in lbl.read_text().splitlines():
        t = ln.split()
        if len(t) == 5:
            c, cx, cy, w, h = int(t[0]), *map(float, t[1:])
            out.append({"cls": c, "box": [(cx-w/2)*W, (cy-h/2)*H, (cx+w/2)*W, (cy+h/2)*H]})
    return out

def parse_stem(stem):
    for c in sorted(CLASS_NAMES, key=len, reverse=True):
        if stem.startswith(c + "_"):
            return c, stem[len(c)+1:].split("_")[0]
    return "unknown", "unknown"

test_imgs = sorted(str(p) for p in (Path(DATA_ROOT) / "test" / "images").iterdir())
pred_cache, CHUNK = {}, 32
for i in tqdm(range(0, len(test_imgs), CHUNK), desc="I-JEPA@20% test sweep"):
    chunk = test_imgs[i:i+CHUNK]
    for src, r in zip(chunk, ijepa_best.predict(chunk, imgsz=IMGSZ, conf=CONF_EVAL,
                                                iou=IOU_NMS, device=DEVICE, verbose=False)):
        preds = []
        if r.boxes is not None:
            for b, c, s in zip(r.boxes.xyxy.cpu().numpy(),
                               r.boxes.cls.cpu().numpy().astype(int),
                               r.boxes.conf.cpu().numpy()):
                preds.append({"cls": int(c), "box": b.tolist(), "score": float(s)})
        pred_cache[Path(src).name] = preds

rows = []
for img in test_imgs:
    gt, preds = gt_for(img), pred_cache[Path(img).name]
    used, tp = set(), 0
    for pr in sorted(preds, key=lambda p: -p["score"]):
        best_i, best_g = 0, None
        for gi, g in enumerate(gt):
            if gi in used or g["cls"] != pr["cls"]:
                continue
            i_ = iou_xyxy(pr["box"], g["box"])
            if i_ > best_i:
                best_i, best_g = i_, gi
        if best_g is not None and best_i >= 0.5:
            used.add(best_g); tp += 1
    cname, scen = parse_stem(Path(img).stem)
    rows.append({"image": img, "class_name": cname, "scenario": scen,
                 "fn": len(gt) - tp, "fp": len(preds) - tp,
                 "side": (gt[0]["box"][2]-gt[0]["box"][0]) if gt else np.nan})
err = pd.DataFrame(rows)
err.to_csv(f"{WORK_ROOT}/ijepa20_test_errors.csv", index=False)
print(f"FN frames: {(err.fn>0).sum()} ({(err.fn>0).mean():.2%}) | FP boxes: {err.fp.sum()}")
print("FN rate by scenario:", err.groupby("scenario").fn.mean().round(4).to_dict(),
      " (Part A signature: evening worst)")
# Out:
# I-JEPA@20% test sweep:   0%|          | 0/65 [00:00<?, ?it/s]
# FN frames: 126 (6.12%) | FP boxes: 337
# FN rate by scenario: {'cloudy': 0.0237, 'evening': 0.0806, 'sunny': 0.0782}  (Part A signature: evening worst)

# %%
def zoom_window(box, W, H, factor=3.0, min_side=90):
    x1, y1, x2, y2 = box
    cx, cy = (x1+x2)/2, (y1+y2)/2
    side = max(x2-x1, y2-y1, min_side) * factor
    return (int(max(0, cx-side/2)), int(max(0, cy-side/2)),
            int(min(W, cx+side/2)), int(min(H, cy+side/2)))

def draw(ax, im, gt, preds, off=(0, 0)):
    ox, oy = off
    ax.imshow(im); ax.set_axis_off()
    for g in gt:
        x1, y1, x2, y2 = g["box"]
        ax.add_patch(mpatches.Rectangle((x1-ox, y1-oy), x2-x1, y2-y1,
                                        fill=False, edgecolor="lime", lw=2))
    for p in preds:
        x1, y1, x2, y2 = p["box"]
        ax.add_patch(mpatches.Rectangle((x1-ox, y1-oy), x2-x1, y2-y1, fill=False,
                                        edgecolor="red", lw=1.8, linestyle="--"))
        ax.text(x1-ox, y1-oy-4, f"{CLASS_NAMES[p['cls']]} {p['score']:.2f}",
                color="red", fontsize=8)

def panel(frame, title, n=4):
    frame = frame.head(n)
    if frame.empty:
        print(title, "- no cases"); return
    fig, axes = plt.subplots(2, len(frame), figsize=(5.6*len(frame), 9))
    axes = np.atleast_2d(axes)
    for col, (_, r) in enumerate(frame.iterrows()):
        im = np.array(Image.open(r.image).convert("RGB")); H, W = im.shape[:2]
        gt, preds = gt_for(r.image), pred_cache[Path(r.image).name]
        draw(axes[0, col], im, gt, preds)
        axes[0, col].set_title(f"{r.class_name} · {r.scenario}", fontsize=10)
        anchor = gt[0]["box"] if gt else (preds[0]["box"] if preds else [0, 0, W, H])
        zx1, zy1, zx2, zy2 = zoom_window(anchor, W, H)
        draw(axes[1, col], im[zy1:zy2, zx1:zx2], gt, preds, off=(zx1, zy1))
        axes[1, col].set_title("zoom 3x", fontsize=9)
    fig.suptitle(title + "  (GT green, predictions red; row 2 zoomed)")
    plt.tight_layout(); plt.show()

ok = err[(err.fn == 0) & (err.fp == 0)]
panel(ok.sample(min(4, len(ok)), random_state=PARTB_SEED), "SUCCESSES — I-JEPA@20%")
bad = err[(err.fn > 0) | (err.fp > 0)].sort_values("side")
panel(bad, "FAILURES — I-JEPA@20% (smallest drones first)")

# %% [markdown]
# ## 11. Export & Hand-off
# | Artifact | Path |
# |---|---|
# | Fine-tuned detectors | `checkpoints/partB_{ijepa,random,coco}_rho20_best.pt` |
# | Per-run metrics (reused by 1b/2b/4b) | `partB_downstream/{ijepa,random,coco}.json` (+ `reference_100pct.json`) |
# | Curves / PR / errors | `ijepa20_curves.png`, evaluation PR plot, `ijepa20_test_errors.csv` |
#
# Per the §4.2 note: once 1b/2b/4b are done, the **method ranking table** (Section 9) picks the
# winner, whose `partB_<method>_rho20_best.pt` is published as a Kaggle dataset for the
# tracking notebook.

# %%
manifest = {"notebook": "partB-03b-ijepa-detect", "rho": RHO, "seed": PARTB_SEED,
            "protocol": {"epochs": EPOCHS, "imgsz": IMGSZ, "batch": BATCH,
                         "patience": PATIENCE, "optimizer": OPTIMIZER, "lr0": LR0,
                         "close_mosaic": CLOSE_MOSAIC, "fliplr": FLIPLR},
            "runs": {k: v["checkpoint"] for k, v in results.items()},
            "test_mAP50_95": {k: v["test_mAP50_95"] for k, v in results.items()}}
Path(f"{WORK_ROOT}/partB_03b_manifest.json").write_text(json.dumps(manifest, indent=2))
print(json.dumps(manifest, indent=2))
for p in Path(CKPT_OUT).glob("partB_*"):
    print(f"[OK] {p.name:<38} {p.stat().st_size/1e6:>7.1f} MB")
# Out:
# {
#   "notebook": "partB-03b-ijepa-detect",
#   "rho": 0.2,
#   "seed": 445,
#   "protocol": {
#     "epochs": 50,
#     "imgsz": 640,
#     "batch": 16,
#     "patience": 25,
#     "optimizer": "auto",
#     "lr0": 0.01,
#     "close_mosaic": 10,
#     "fliplr": 0.5
#   },
#   "runs": {
#     "ijepa": "/kaggle/working/checkpoints/partB_ijepa_rho20_best.pt",
#     "random": "/kaggle/working/checkpoints/partB_random_rho20_best.pt",
#     "coco": "/kaggle/working/checkpoints/partB_coco_rho20_best.pt"
#   },
#   "test_mAP50_95": {
#     "ijepa": 0.6085,
#     "random": 0.5928,
#     "coco": 0.6224
#   }
# }
# [OK] partB_ijepa_rho20_best.pt                 20.3 MB
# [OK] partB_coco_rho20_best.pt                  20.3 MB
# [OK] partB_random_rho20_best.pt                20.3 MB

# %% [markdown]
# ## 12. Pre-Commit Checklist
# - [ ] Subset counts + per-class instances printed; disjointness `[OK]`
# - [ ] **Mapping report table** rendered with the SSL/random split and the two checksum proofs
# - [ ] Demo inference, training curves, PR curve, val+test metrics for all three runs visible
# - [ ] Comparison table + value-added deltas printed (and reference line if attached)
# - [ ] Success/failure panels + per-scenario FN rates visible
# - [ ] Checkpoints + `partB_downstream/*.json` listed `[OK]`; committed Public
